# %%
import numpy as np
import pandas as pd
import gdown

# %%
# Google Drive file ID
file_id = '1uEUvgf4t9SVIrH1DSMf5NGZtJCSq81bC'

# Define the file path where you want to save the downloaded file
file_path = '/content/dataset.csv'
# Download the file from Google Drive using its file ID
gdown.download(f'https://drive.google.com/uc?id={file_id}', file_path, quiet=False)

# Read the downloaded data into a Pandas DataFrame
filtered_data = pd.read_csv(file_path).astype(str)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1uEUvgf4t9SVIrH1DSMf5NGZtJCSq81bC
# To: /content/dataset.csv
# 100%|██████████| 86.9M/86.9M [00:00<00:00, 160MB/s]

# %%
filtered_data
# Out:
#        job_id Application ID     js_id Application State Application Score_x  \
# 0       80546       12895143  ae7c0b81       Shortlisted                  55
# 1       24626       13029639  ae7c0b81                Ok                  62
# 2       32636       16702294  ae7c0b81       Shortlisted                  80
# 3       24149       17265467  ae7c0b81       Shortlisted                  78
# 4        3307       17265708  ae7c0b81       Shortlisted                  72
# ...       ...            ...       ...               ...                 ...
# 158461  64316       25342682  df7bbbfc                Ok                  46
# 158462  15735       25786958  a33fd468                Ok                  65
# 158463  75000       25855824  9964ae88                Ok                  51
# 158464  83709       26128359  87ef40dd                Ok                  31
# 158465   9402       26128817  79d81893                Ok                  57
#
# ...

# %%
# Google Drive file ID
file_id = '18QhhMQHX-qGqKiqZ-psBCOEIE0tNU5fe'

# Define the file path where you want to save the downloaded file
file_path = '/content/dataset.csv'
# Download the file from Google Drive using its file ID
gdown.download(f'https://drive.google.com/uc?id={file_id}', file_path, quiet=False)

# Read the downloaded data into a Pandas DataFrame
jobs_clean = pd.read_csv(file_path).astype(str)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=18QhhMQHX-qGqKiqZ-psBCOEIE0tNU5fe
# To: /content/dataset.csv
# 100%|██████████| 87.7M/87.7M [00:00<00:00, 180MB/s]
# <ipython-input-26-2c52a1d23728>:10: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   jobs_clean = pd.read_csv(file_path).astype(str)

# %%
jobs_clean
# Out:
#        job_id                                            title  \
# 0       31036                          Banking Account Manager
# 1       68350  Kitchen Designer - Madinaty and Obour Branches
# 2       19130             Human Resources Manager - HR Manager
# 3       62882                                   UI/UX Designer
# 4       50355           Senior Sales Consultant - Real Estate
# ...       ...                                              ...
# 138566  43292                     Fleet Maintenance Supervisor
# 138567  46969                                          medicin
# 138568  68006                            GIS Solution Engineer
# 138569  77613                                 Product Manager
# 138570  54285                                     Receptionist
#
#                                              requirements  \
# 0                      Education  Bachelor of Business...
# 1                      Fine arts  app ed arts graduate...
# ...

# %%
# Check for duplicated rows in the DataFrame
duplicated_rows = jobs_clean.duplicated()

# Display the count of duplicated rows
print("Number of duplicated rows:", duplicated_rows.sum())

# Display the duplicated rows themselves (if any)
duplicated_rows_data = jobs_clean[duplicated_rows]
print("Duplicated rows:")
print(duplicated_rows_data)
# Out:
# Number of duplicated rows: 1
# Duplicated rows:
#        job_id                                              title  \
# 13443  115719   the world’s largest #remotework company is lo...
#
#                                             requirements  \
# 13443   resolving discrepancies and collaborating acr...
#
#            work_experience_years_min     posted_at
# 13443   Accounts Receivable (or OTC)   Controlling

# %%
# Remove duplicated rows and reset index in the original DataFrame
jobs_clean.drop_duplicates(inplace=True)
jobs_clean.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Dropping unnessary columns in jobs_clean table

# %%
# Drop specified columns in the original DataFrame
jobs_clean.drop(['work_experience_years_min', 'posted_at'], axis=1, inplace=True)

# %%
jobs_clean
# Out:
#        job_id                                            title  \
# 0       31036                          Banking Account Manager
# 1       68350  Kitchen Designer - Madinaty and Obour Branches
# 2       19130             Human Resources Manager - HR Manager
# 3       62882                                   UI/UX Designer
# 4       50355           Senior Sales Consultant - Real Estate
# ...       ...                                              ...
# 138565  43292                     Fleet Maintenance Supervisor
# 138566  46969                                          medicin
# 138567  68006                            GIS Solution Engineer
# 138568  77613                                 Product Manager
# 138569  54285                                     Receptionist
#
#                                              requirements
# 0                      Education  Bachelor of Business...
# 1                      Fine arts  app ed arts graduate...
# ...

# %% [markdown]
# ###  joinning two tables: filtered_data and jobs_clean using job_id columns

# %%
# Assuming 'job_id' is the common column between the two DataFrames
merged_data = pd.merge(filtered_data, jobs_clean, on='job_id')

# %%
# Display the merged DataFrame
merged_data
# Out:
#        job_id Application ID     js_id Application State Application Score_x  \
# 0       80546       12895143  ae7c0b81       Shortlisted                  55
# 1       80546       12948846  6aa9507f       Shortlisted                  62
# 2       80546       13331886  15005ab6                Ok                  62
# 3       24626       13029639  ae7c0b81                Ok                  62
# 4       24626       13019867  933a05b3                Ok                  70
# ...       ...            ...       ...               ...                 ...
# 142444  13496       23541315  e39877ec                Ok                  53
# 142445  67273       24957718  12a991cc                Ok                  57
# 142446  24489       18460254  7650619c                Ok                  30
# 142447  47510       19214309  f05f6ab6                Ok                  61
# 142448  49197       24791945  026ce50a                Ok                  51
#
# ...

# %% [markdown]
# ### Check for Null Values:

# %%
# Check for null values in the merged DataFrame
null_counts = merged_data.isnull().sum()

# Display the count of null values for each column
print("Null values in each column:")
print(null_counts)
# Out:
# Null values in each column:
# job_id                     0
# Application ID             0
# js_id                      0
# Application State          0
# Application Score_x        0
# Application Score_y        0
# text_without_stopwords     0
# job_titles                 0
# career_level               0
# js_preference_work_role    0
# title                      0
# requirements               0
# dtype: int64

# %% [markdown]
# ### Check for Duplicated Rows:

# %%
# Check for duplicated rows in the merged DataFrame
duplicated_rows = merged_data.duplicated()

# Display the count of duplicated rows
print("Number of duplicated rows:", duplicated_rows.sum())
# Out:
# Number of duplicated rows: 197

# %% [markdown]
# #### Deleting dublicates

# %%
# Drop duplicate rows in the merged DataFrame
merged_data.drop_duplicates(inplace=True)

# %% [markdown]
# #### Reseting index

# %%
# Reset index after dropping duplicates
merged_data.reset_index(drop=True, inplace=True)

# %%
# Display the DataFrame after dropping duplicates
merged_data
# Out:
#        job_id Application ID     js_id Application State Application Score_x  \
# 0       80546       12895143  ae7c0b81       Shortlisted                  55
# 1       80546       12948846  6aa9507f       Shortlisted                  62
# 2       80546       13331886  15005ab6                Ok                  62
# 3       24626       13029639  ae7c0b81                Ok                  62
# 4       24626       13019867  933a05b3                Ok                  70
# ...       ...            ...       ...               ...                 ...
# 142247  13496       23541315  e39877ec                Ok                  53
# 142248  67273       24957718  12a991cc                Ok                  57
# 142249  24489       18460254  7650619c                Ok                  30
# 142250  47510       19214309  f05f6ab6                Ok                  61
# 142251  49197       24791945  026ce50a                Ok                  51
#
# ...

# %% [markdown]
# ### Saving final results

# %%
merged_data.to_csv("Merged_data_info_requirements.csv")
