# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import re

# %%
job_pref=pd.read_csv('/content/drive/MyDrive/job_preference_aggregated')
final_arabic_records=pd.read_csv('/content/drive/MyDrive/Graduation_Data/final_arabic_records.csv')
Application_Score=pd.read_csv('/content/drive/MyDrive/Graduation_Data/Application_Score.csv')
skills_aggregate=pd.read_csv('/content/drive/MyDrive/Graduation_Data/skills_aggregate.csv')

# %%
before=pd.read_csv('/content/drive/MyDrive/Graduation_Data/skills_aggregate.csv')
before

# %%
job_pref
# Out:
#            js_id                                         job_titles  \
# 0       00002844  Data analysis,Backoffice, Data analysis,Backof...
# 1       00003033                               manager ,accounting
# 2       0000c926  Commerce, ,Banking ,Fashion ,Sales,Tourism com...
# 3       0000f63d                 Fashion ,Service, Fashion ,Service
# 4       000163ae               Retail sales manager ,Sales manager
# ...          ...                                                ...
# 386823  ffffbf23  Translating English texts To Arabic,Teaching E...
# 386824  ffffcc01  Interior fitout managment ,Interior fitout exe...
# 386825  ffffcfa7                                   teacher,educator
# 386826  ffffda1b  Office manager,cordnaitor,Executive Secretary,...
# 386827  fffffdf7                       Teaching,Assistant Professor
#
#                             career_level  \
# 0              Experienced (Non-Manager)
# 1                                Student
# ...

# %%
final_arabic_records
# Out:
#           js_id                                         job_titles  \
# 0      0006cc50                                      Qan,ni,qan,ni
# 1      000aa814   Purchasing specialist, purchasing representative
# 2      002261db                    Tax accountant, cost accountant
# 3      0024d630  Administrative jobs, central jobs, administrat...
# 4      002af174  Teacher, secretary, administrator, teacher, se...
# ...         ...                                                ...
# 12612  ffcef56d                 Quality, monitor, quality, monitor
# 12613  ffcfefa7  Inside sales, marketing, inside sales, marketi...
# 12614  ffd48751  I am looking for, for, free, jobs. I am lookin...
# 12615  ffeb36a6   Media, public relations, media, public relations
# 12616  fffd09bc                           Security guard, musician
#
#                     career_level  \
# 0                    Entry Level
# 1                        Student
# 2                        Student
# ...

# %%
Application_Score
# Out:
#            js_id  Application Score
# 0       00001b94          60.000000
# 1       00006665          36.333333
# 2       000072b8          38.000000
# 3       000086f5          33.000000
# 4       0000cd8f          55.000000
# ...          ...                ...
# 376551  ffff4ee9          53.000000
# 376552  ffff5f7a          45.666667
# 376553  ffff68cc          59.800000
# 376554  ffff9ce9          51.333333
# 376555  ffffbf23          42.000000
#
# [376556 rows x 2 columns]

# %%
skills_aggregate
# Out:
#            js_id                             text_without_stopwords
# 0       00001b94  civilengineering quantitiesengineer procuremen...
# 1       0000250e  computerskills salesskills •presentationskills...
# 2       00002844  excellentdocumentationreporting excellentdatab...
# 3       00003033                                   computer reading
# 4       000072b8                                       exell msword
# ...          ...                                                ...
# 603148  ffffbf23                      photography photoshopprograms
# 603149  ffffc256  aws-cwi cswip3.1 bgas asntlevel2rtutmtpt autoc...
# 603150  ffffcc01                            autocad microsoftoffice
# 603151  ffffcfa7                                   msword craftwork
# 603152  ffffda1b                                hardskills teaching
#
# [603153 rows x 2 columns]

# %%
js_id_value = '000aa814'
row = job_pref.loc[job_pref['js_id'] == js_id_value]
row
job_title = row['job_titles'].values[0]
job_title
# Out:
# 'اخصائي مشتريات,مندوب مشتريات'

# %%
js_id_value = '000aa814'
row = final_arabic_records.loc[final_arabic_records['js_id'] == js_id_value]
row
# Out:
#       js_id                                        job_titles career_level  \
# 1  000aa814  Purchasing specialist, purchasing representative      Student
#
#   js_preference_work_role
# 1  Purchasing/Procurement

# %%
import pandas as pd

# Merge the two datasets based on 'js_id'
merged_dataset = job_pref.merge(final_arabic_records[['js_id', 'job_titles']], on='js_id', how='left')

# Replace the 'job_titles' in 'job_pref' with the corresponding values from 'final_arabic_records'
merged_dataset['job_titles_x'] = merged_dataset['job_titles_y'].combine_first(merged_dataset['job_titles_x'])

# Drop the redundant columns
merged_dataset = merged_dataset.drop(columns=['job_titles_y'])

# Rename the updated column to 'job_titles'
merged_dataset = merged_dataset.rename(columns={'job_titles_x': 'job_titles'})

# Save the updated dataset to a new CSV file or replace the original one
merged_dataset.to_csv('updated_job_pref2.csv', index=False)  # Replace 'updated_job_pref.csv' with your desired file path

# %%
merged_dataset
# Out:
#            js_id                                         job_titles  \
# 0       00002844  Data analysis,Backoffice, Data analysis,Backof...
# 1       00003033                               manager ,accounting
# 2       0000c926  Commerce, ,Banking ,Fashion ,Sales,Tourism com...
# 3       0000f63d                 Fashion ,Service, Fashion ,Service
# 4       000163ae               Retail sales manager ,Sales manager
# ...          ...                                                ...
# 386823  ffffbf23  Translating English texts To Arabic,Teaching E...
# 386824  ffffcc01  Interior fitout managment ,Interior fitout exe...
# 386825  ffffcfa7                                   teacher,educator
# 386826  ffffda1b  Office manager,cordnaitor,Executive Secretary,...
# 386827  fffffdf7                       Teaching,Assistant Professor
#
#                             career_level  \
# 0              Experienced (Non-Manager)
# 1                                Student
# ...

# %%
# import pandas as pd


# # Create a mapping between job_titles and js_id from the job_pref dataset
# mapping = final_arabic_records[['job_titles', 'js_id']]

# # Merge the final_arabic_records dataset with the mapping
# job_pref = job_pref.merge(mapping, on='job_titles', how='left')

# # Rename the column to 'js_id' (if necessary)
# job_pref.rename(columns={'js_id_x': 'js_id'}, inplace=True)

# # Drop the extra column (js_id_y) if necessary
# job_pref.drop('js_id_y', axis=1, inplace=True)

# # Save the updated dataset if needed
# job_pref.to_csv('updated_final_arabic_records.csv', index=False)

# %%
js_id_value = '000aa814'
row = merged_dataset.loc[job_pref['js_id'] == js_id_value]
row
job_title = row['job_titles'].values[0]
job_title
# Out:
# 'Purchasing specialist, purchasing representative'

# %%
js_id_value = '000aa814'
row = merged_dataset.loc[job_pref['js_id'] == js_id_value]
row
# Out:
#        js_id                                        job_titles career_level  \
# 48  000aa814  Purchasing specialist, purchasing representative      Student
#
#    js_preference_work_role
# 48  Purchasing/Procurement

# %%
js_id_value = '000aa814'
row = job_pref.loc[job_pref['js_id'] == js_id_value]
row
job_title = row['job_titles'].values[0]
job_title
# Out:
# 'اخصائي مشتريات,مندوب مشتريات'

# %%
js_id_value = '000aa814'
row = merged_records.loc[job_pref['js_id'] == js_id_value]
row
job_title = merged_dataset['job_titles'].values[0]

js_id_value = '000aa814'
row = final_arabic_records.loc[final_arabic_records['js_id'] == js_id_value]
row
# Out:
#       js_id                                        job_titles career_level  \
# 1  000aa814  Purchasing specialist, purchasing representative      Student
#
#   js_preference_work_role
# 1  Purchasing/Procurement

# %%
# job_pref.to_csv()
